# %% [markdown]
# Q1. Explain GET and POST methods.

# %% [markdown]
# Ans:
#
#     GET and POST both are Http methods to request and send data.
#
# GET:
#
#     GET requests can be cached
#     GET requests remain in the browser history
#     GET requests can be bookmarked
#     GET requests should never be used when dealing with sensitive data
#     GET requests have length restrictions
#     GET requests are only used to request data (not modify)
#
# POST:
#
#     POST requests are never cached
#     POST requests do not remain in the browser history
#     POST requests cannot be bookmarked
#     POST requests have no restrictions on data length

# %% [markdown]
# Q2. Why is request used in Flask?

# %% [markdown]
# Ans:
#
#     To access the incoming data in Flask, we use the request object. The request object holds all incoming data from the request, which includes the mimetype, referrer, IP address, raw data, HTTP method, and headers, among other things.

# %% [markdown]
# Q3. Why is redirect() used in Flask?

# %% [markdown]
# Ans:
#
#     it is used to returns a response object and to redirect the user to another target location with specified status code.

# %% [markdown]
# Q4. What are templates in Flask? Why is the render_template() function used?

# %% [markdown]
# Ans:
#
#     Templates are files that contain static data as well as placeholders for dynamic data.
#     render_template() function is used to render html pages as output in flask

# %% [markdown]
# Q5. Create a simple API. Use Postman to test it. Attach the screenshot of the output in the Jupyter Notebook.

# %%
from flask import Flask, request, jsonify

app = Flask(__name__)

@app.route('/')
def welcome():
    return '<h1>Welcome to the page</h1>'

@app.route('/api/sum', methods=['POST'])
def addition():
    num1 = int(request.json['num1'])
    num2 = int(request.json['num2'])
    result = num1 + num2

    return jsonify(result)

if __name__ == '__main__':
    app.run()

# %% [markdown]
# ![image.png](attachment:69dacfa5-87e5-4a1a-96d0-5b2503f596e5.png)
